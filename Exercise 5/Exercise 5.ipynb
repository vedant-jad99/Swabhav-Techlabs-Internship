# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_json('emp.json')

# %%
df
# Out:
#     ID1       Name       Role   ID2       Date    ID3    ID4  ID5
# 0   7698     BLAKE    MANAGER  7839 1981-05-01   2850   NULL   30
# 1   7369     SMITH      CLERK  7902 1980-12-17    800   NULL   20
# 2   7788     SCOTT    ANALYST  7566 1982-12-09   3000   NULL   20
# 3   7934    MILLER      CLERK  7782 1982-01-23   1300   NULL   10
# 4   7654    MARTIN   SALESMAN  7698 1981-09-28   1250   1400   30
# 5   7499     ALLEN   SALESMAN  7698 1981-02-20   1600    300   30
# 6   7782     CLARK    MANAGER  7839 1981-06-09   2450  NULL    10
# 7   7844    TURNER   SALESMAN  7698 1981-09-08   1500      0   30
# 8   7900     JAMES      CLERK  7698 1981-12-03    950   NULL   30
# 9    721      WARD   SALESMAN  7698 1981-02-22   1250    500   30
# 10  7902      FORD    ANALYST  7566 1981-12-03   3000   NULL   20
# 11  7876     ADAMS      CLERK  7788 1981-01-12   1100   NULL   20
# 12  7566     JONES    MANAGER  7839 1981-04-02   2875   NULL   20
# ...

# %%
df['Role'].unique()
# Out:
# array(['MANAGER', 'CLERK', 'ANALYST', 'SALESMAN', 'PRESIDENT'],
#       dtype=object)

# %%
df=pd.read_csv('marks_frame.csv',header=None,names=['name','lang','score'])

# %%
df
# Out:
#            name    lang  score
# 0        Saurav    Java   90.0
# 1       Harshit  Python   95.0
# 2       Vaibhav    Java   80.0
# 3        Nitesh       C   90.0
# 4      Kartikey    HTML   98.0
# 5         Kunal    Java   60.0
# 6  Venkateshwar  Python   70.0
# 7        Akshay  Python    NaN
# 8       Ratnesh     NaN   60.0

# %%
q1=df['score'].quantile(0)
q2=df['score'].quantile(0.5)
q3=df['score'].quantile(0.75)

# %%
pd.cut(df['score'],[0,q1,q2,q3,100],labels=['q1','q2','q3','q4'])
# Out:
# 0     q3
# 1     q4
# 2     q2
# 3     q3
# 4     q4
# 5     q1
# 6     q2
# 7    NaN
# 8     q1
# Name: score, dtype: category
# Categories (4, object): [q1 < q2 < q3 < q4]

# %%
df=pd.read_csv('SalaryData.csv')

# %%
df[]
# Out:
#      exp  salary
# 0    1.1   39343
# 1    1.3   46205
# 2    1.5   37731
# 3    2.0   43525
# 4    2.2   39891
# 5    2.9   56642
# 6    3.0   60150
# 7    3.2   54445
# 8    3.2   64445
# 9    3.7   57189
# 10   3.9   63218
# 11   4.0   55794
# 12   4.0   56957
# 13   4.1   57081
# 14   4.5   61111
# 15   4.9   67938
# 16   5.1   66029
# 17   5.3   83088
# 18   5.9   81363
# 19   6.0   93940
# 20   6.8   91738
# 21   7.1   98273
# 22   7.9  101302
# 23   8.2  113812
# 24   8.7  109431
# 25   9.0  105582
# 26   9.5  116969
# 27   9.6  112635
# 28  10.3  122391
# 29  10.5  121872
# 30  11.2  127345
# 31  11.5  126756
# 32  12.3  128765
# 33  12.9  135675
# 34  13.5  139465

# %%
np.argmax(df['salary'])
# Out:
# 34

# %%
df=pd.read_json('emp.json')

# %%
df
# Out:
#     ID1       Name       Role   ID2       Date    ID3    ID4  ID5
# 0   7698     BLAKE    MANAGER  7839 1981-05-01   2850   NULL   30
# 1   7369     SMITH      CLERK  7902 1980-12-17    800   NULL   20
# 2   7788     SCOTT    ANALYST  7566 1982-12-09   3000   NULL   20
# 3   7934    MILLER      CLERK  7782 1982-01-23   1300   NULL   10
# 4   7654    MARTIN   SALESMAN  7698 1981-09-28   1250   1400   30
# 5   7499     ALLEN   SALESMAN  7698 1981-02-20   1600    300   30
# 6   7782     CLARK    MANAGER  7839 1981-06-09   2450  NULL    10
# 7   7844    TURNER   SALESMAN  7698 1981-09-08   1500      0   30
# 8   7900     JAMES      CLERK  7698 1981-12-03    950   NULL   30
# 9    721      WARD   SALESMAN  7698 1981-02-22   1250    500   30
# 10  7902      FORD    ANALYST  7566 1981-12-03   3000   NULL   20
# 11  7876     ADAMS      CLERK  7788 1981-01-12   1100   NULL   20
# 12  7566     JONES    MANAGER  7839 1981-04-02   2875   NULL   20
# ...

# %%
k=df[df['Name']=='SMITH']['ID5']
print(k)
df[df['ID5']==int(k)]
# Out:
# 1    20
# Name: ID5, dtype: int64
#     ID1    Name     Role   ID2       Date   ID3   ID4  ID5
# 1   7369  SMITH    CLERK  7902 1980-12-17   800  NULL   20
# 2   7788  SCOTT  ANALYST  7566 1982-12-09  3000  NULL   20
# 10  7902   FORD  ANALYST  7566 1981-12-03  3000  NULL   20
# 11  7876  ADAMS    CLERK  7788 1981-01-12  1100  NULL   20
# 12  7566  JONES  MANAGER  7839 1981-04-02  2875  NULL   20

# %%
grp=df.groupby(by=['Role','ID5'])
grp['Role'].value_counts()
# Out:
# Role       ID5  Role
# ANALYST    20   ANALYST      2
# CLERK      10   CLERK        1
#            20   CLERK        2
#            30   CLERK        1
# MANAGER    10   MANAGER      1
#            20   MANAGER      1
#            30   MANAGER      1
# PRESIDENT  10   PRESIDENT    1
# SALESMAN   30   SALESMAN     4
# Name: Role, dtype: int64

# %%
df.pivot_table(index=['Role'],aggfunc=['mean'],values=['ID5'])
# Out:
#           mean
#            ID5
# Role
# ANALYST     20
# CLERK       20
# MANAGER     20
# PRESIDENT   10
# SALESMAN    30

# %%
df=pd.read_json('https://restcountries.eu/rest/v2/all',)

# %%
df
# Out:
#                   name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0          Afghanistan          [.af]         AF        AFG         [93]
# 1        Åland Islands          [.ax]         AX        ALA        [358]
# 2              Albania          [.al]         AL        ALB        [355]
# 3              Algeria          [.dz]         DZ        DZA        [213]
# 4       American Samoa          [.as]         AS        ASM       [1684]
# ..                 ...            ...        ...        ...          ...
# 245  Wallis and Futuna          [.wf]         WF        WLF        [681]
# 246     Western Sahara          [.eh]         EH        ESH        [212]
# 247              Yemen          [.ye]         YE        YEM        [967]
# 248             Zambia          [.zm]         ZM        ZMB        [260]
# 249           Zimbabwe          [.zw]         ZW        ZWE        [263]
#
#        capital                                       altSpellings   region  \
# ...

# %%
grp=df.groupby(by='region')

# %%
grp['name'].count()
# Out:
# region
#              2
# Africa      60
# Americas    57
# Asia        50
# Europe      53
# Oceania     27
# Polar        1
# Name: name, dtype: int64

# %%
df.nlargest(5, ['population'])
# Out:
#                          name topLevelDomain alpha2Code alpha3Code  \
# 48                      China          [.cn]         CN        CHN
# 104                     India          [.in]         IN        IND
# 239  United States of America          [.us]         US        USA
# 105                 Indonesia          [.id]         ID        IDN
# 31                     Brazil          [.br]         BR        BRA
#
#     callingCodes           capital  \
# 48          [86]           Beijing
# 104         [91]         New Delhi
# 239          [1]  Washington, D.C.
# 105         [62]           Jakarta
# 31          [55]          Brasília
#
#                                           altSpellings    region  \
# 48   [CN, Zhōngguó, Zhongguo, Zhonghua, People's Re...      Asia
# 104   [IN, Bhārat, Republic of India, Bharat Ganrajya]      Asia
# 239                [US, USA, United States of America]  Americas
# 105    [ID, Republic of Indonesia, Republik Indonesia]      Asia
# ...

# %%
df[df['area']>500000]
# Out:
#                                    name topLevelDomain alpha2Code alpha3Code  \
# 0                           Afghanistan          [.af]         AF        AFG
# 3                               Algeria          [.dz]         DZ        DZA
# 6                                Angola          [.ao]         AO        AGO
# 8                            Antarctica          [.aq]         AQ        ATA
# 10                            Argentina          [.ar]         AR        ARG
# 13                            Australia          [.au]         AU        AUS
# 26     Bolivia (Plurinational State of)          [.bo]         BO        BOL
# 29                             Botswana          [.bw]         BW        BWA
# 31                               Brazil          [.br]         BR        BRA
# 42                               Canada          [.ca]         CA        CAN
# 45             Central African Republic          [.cf]         CF        CAF
# ...

# %%
df.nlargest(5,'area')
# Out:
#                          name topLevelDomain alpha2Code alpha3Code  \
# 185        Russian Federation          [.ru]         RU        RUS
# 8                  Antarctica          [.aq]         AQ        ATA
# 42                     Canada          [.ca]         CA        CAN
# 48                      China          [.cn]         CN        CHN
# 239  United States of America          [.us]         US        USA
#
#     callingCodes           capital  \
# 185          [7]            Moscow
# 8          [672]
# 42           [1]            Ottawa
# 48          [86]           Beijing
# 239          [1]  Washington, D.C.
#
#                                           altSpellings    region  \
# 185  [RU, Rossiya, Russian Federation, Российская Ф...    Europe
# 8                                                   []     Polar
# 42                                                [CA]  Americas
# 48   [CN, Zhōngguó, Zhongguo, Zhonghua, People's Re...      Asia
# ...

# %%
df.nsmallest(5,'area')
# Out:
#                         name topLevelDomain alpha2Code alpha3Code  \
# 99                  Holy See          [.va]         VA        VAT
# 147                   Monaco          [.mc]         MC        MCO
# 86                 Gibraltar          [.gi]         GI        GIB
# 227                  Tokelau          [.tk]         TK        TKL
# 50   Cocos (Keeling) Islands          [.cc]         CC        CCK
#
#     callingCodes      capital  \
# 99         [379]         Rome
# 147        [377]       Monaco
# 86         [350]    Gibraltar
# 227        [690]      Fakaofo
# 50          [61]  West Island
#
#                                           altSpellings   region  \
# 99                [Sancta Sedes, Vatican, The Vatican]   Europe
# 147  [MC, Principality of Monaco, Principauté de Mo...   Europe
# 86                                                [GI]   Europe
# 227                                               [TK]  Oceania
# ...

# %%
df.nlargest(1,'area')
# Out:
#                    name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 185  Russian Federation          [.ru]         RU        RUS          [7]
#
#     capital                                       altSpellings  region  \
# 185  Moscow  [RU, Rossiya, Russian Federation, Российская Ф...  Europe
#
#           subregion  population  ...  \
# 185  Eastern Europe   146599183  ...
#
#                                              timezones  \
# 185  [UTC+03:00, UTC+04:00, UTC+06:00, UTC+07:00, U...
#
#                                                borders  nativeName  \
# 185  [AZE, BLR, CHN, EST, FIN, GEO, KAZ, PRK, LVA, ...      Россия
#
#      numericCode                                         currencies  \
# 185        643.0  [{'code': 'RUB', 'name': 'Russian ruble', 'sym...
#
#                                              languages  \
# 185  [{'iso639_1': 'ru', 'iso639_2': 'rus', 'name':...
#
#                                           translations  \
# ...

# %%
df['population'][185]
# Out:
# 146599183

# %%
df[df['name'].str.startswith('I')]
# Out:
#                            name topLevelDomain alpha2Code alpha3Code  \
# 103                     Iceland          [.is]         IS        ISL
# 104                       India          [.in]         IN        IND
# 105                   Indonesia          [.id]         ID        IDN
# 107  Iran (Islamic Republic of)          [.ir]         IR        IRN
# 108                        Iraq          [.iq]         IQ        IRQ
# 109                     Ireland          [.ie]         IE        IRL
# 110                 Isle of Man          [.im]         IM        IMN
# 111                      Israel          [.il]         IL        ISR
# 112                       Italy          [.it]         IT        ITA
#
#     callingCodes    capital  \
# 103        [354]  Reykjavík
# 104         [91]  New Delhi
# 105         [62]    Jakarta
# 107         [98]     Tehran
# 108        [964]    Baghdad
# 109        [353]     Dublin
# 110         [44]    Douglas
# 111        [972]  Jerusalem
# ...

# %%
df2=pd.DataFrame(df['name']).join(df['borders'])

# %%
df2
# Out:
#                   name                                   borders
# 0          Afghanistan            [IRN, PAK, TKM, UZB, TJK, CHN]
# 1        Åland Islands                                        []
# 2              Albania                      [MNE, GRC, MKD, KOS]
# 3              Algeria       [TUN, LBY, NER, ESH, MRT, MLI, MAR]
# 4       American Samoa                                        []
# ..                 ...                                       ...
# 245  Wallis and Futuna                                        []
# 246     Western Sahara                           [DZA, MRT, MAR]
# 247              Yemen                                [OMN, SAU]
# 248             Zambia  [AGO, BWA, COD, MWI, MOZ, NAM, TZA, ZWE]
# 249           Zimbabwe                      [BWA, MOZ, ZAF, ZMB]
#
# [250 rows x 2 columns]

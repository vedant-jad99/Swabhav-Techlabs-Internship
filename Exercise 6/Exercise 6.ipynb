# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('persons.csv')

# %%
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
mw=df[df['Gender']=='Male']
fw=df[df['Gender']=='Female']

# %%
fig,ax=plt.subplots(1,2)
ax[0].set_title('Male Weight Dist')
ax[0].boxplot(x='Weight',data=mw,showmeans=True,meanline=True)
ax[0].set_xlabel('Male')
ax[0].set_ylabel('Weights in kg')
plt.gcf().set_size_inches(15,8)
ax[1].set_title('Female Weight Dist')
ax[1].boxplot(x='Weight',data=fw,showmeans=True,meanline=True)
ax[1].set_xlabel('Female')
ax[1].set_ylabel('Weights in kg')
plt.gcf().set_size_inches(15,8)

# %%
df=pd.read_csv('Emp.csv')
df
# Out:
#     EMPNO     ENAME        JOB  MGR_ID        DOJ      SAL    COMM  DEPTNO
# 0    7698     BLAKE    MANAGER  7839.0   1-MAY-81   2850.0     NaN      30
# 1    7369     SMITH      CLERK  7902.0  17-DEC-80    800.0     NaN      20
# 2    7788     SCOTT    ANALYST  7566.0  09-DEC-82   3000.0     NaN      20
# 3    7934    MILLER      CLERK  7782.0  23-JAN-82   1300.0     NaN      10
# 4    7654    MARTIN   SALESMAN  7698.0  28-SEP-81   1250.0  1400.0      30
# 5    7499     ALLEN   SALESMAN  7698.0  20-FEB-81   1600.0   300.0      30
# 6    7782     CLARK    MANAGER  7839.0   9-JUN-81   2450.0     NaN      10
# 7    7844    TURNER   SALESMAN  7698.0   8-SEP-81   1500.0     0.0      30
# 8    7900     JAMES      CLERK  7698.0   3-DEC-81    950.0     NaN      30
# 9    7521      WARD   SALESMAN  7698.0  22-FEB-81   1250.0   500.0      30
# 10   7902      FORD    ANALYST  7566.0   3-DEC-81   3000.0     NaN      20
# ...

# %%
plt.pie(data=df,x='SAL',labels='JOB',)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f07d1bdf220>,
# ...
#  [Text(1.071175590583024, 0.2501656533961247, 'MANAGER'),
#   Text(0.9528123811149548, 0.5496804220581721, 'CLERK'),
#   Text(0.7430358760723148, 0.8111089241707601, 'ANALYST'),
#   Text(0.4237624323848373, 1.015098714854514, 'CLERK'),
#   Text(0.2079458103483985, 1.0801659779675288, 'SALESMAN'),
#   Text(-0.043158150541311696, 1.0991530257620428, 'SALESMAN'),
#   Text(-0.39292994085244537, 1.0274269130121587, 'MANAGER'),
#   Text(-0.6944580374571356, 0.8530697710100762, 'SALESMAN'),
#   Text(-0.8481569486818636, 0.7004497058338099, 'CLERK'),
#   Text(-0.9582953488196941, 0.5400648335436598, 'SALESMAN'),
#   Text(-1.0839440870314299, 0.18725708581947037, 'ANALYST'),
#   Text(-1.086126183934917, -0.174154852275138, 'CLERK'),
#   Text(-0.9720955555643855, -0.5148108690111047, 'MANAGER'),
#   Text(0.3908614064266748, -1.0282156198804617, 'PRESIDENT')])

# %%
df=pd.read_json("https://restcountries.eu/rest/v2/all")

# %%
df
# Out:
#                   name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0          Afghanistan          [.af]         AF        AFG         [93]
# 1        Åland Islands          [.ax]         AX        ALA        [358]
# 2              Albania          [.al]         AL        ALB        [355]
# 3              Algeria          [.dz]         DZ        DZA        [213]
# 4       American Samoa          [.as]         AS        ASM       [1684]
# ..                 ...            ...        ...        ...          ...
# 245  Wallis and Futuna          [.wf]         WF        WLF        [681]
# 246     Western Sahara          [.eh]         EH        ESH        [212]
# 247              Yemen          [.ye]         YE        YEM        [967]
# 248             Zambia          [.zm]         ZM        ZMB        [260]
# 249           Zimbabwe          [.zw]         ZW        ZWE        [263]
#
#        capital                                       altSpellings   region  \
# ...

# %%
df_pop=df.nlargest(10, ['population']) 
df_pop
df_pop.columns
# Out:
# Index(['name', 'topLevelDomain', 'alpha2Code', 'alpha3Code', 'callingCodes',
#        'capital', 'altSpellings', 'region', 'subregion', 'population',
#        'latlng', 'demonym', 'area', 'gini', 'timezones', 'borders',
#        'nativeName', 'numericCode', 'currencies', 'languages', 'translations',
#        'flag', 'regionalBlocs', 'cioc'],
#       dtype='object')

# %%
sns.scatterplot(y='population',x='area',data=df_pop,hue='alpha3Code')

# %%
flights=sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
groupedvalues=flights.groupby('year').sum().reset_index()
groupedvalues
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
bars=plt.bar(x='year',data=groupedvalues,height='passengers',)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .005, yval)

# %%
data = {"sizes": [1000,2000,1500,1100,1670,1550,3000,2400,3400,1200], "ages": [5,6,2,10,11,7,5,6,8,1], "prices": [15.5,25.5,22,10.5,30,35,45,25,43,22]}
newdf = pd.DataFrame.from_dict(data)
sns.heatmap(newdf.corr(), annot=True)

# %%
grp=df_pop.groupby(["region"], as_index=False)["population"].sum()
grp=pd.DataFrame(grp)
print(grp)
# Out:
#      region  population
# 0    Africa   186988000
# 1  Americas   530082893
# 2      Asia  3413429018
# 3    Europe   146599183

# %%
grp2=df_pop.groupby(["region"],as_index=False)["area"].sum()
grp2=pd.DataFrame(grp2)
print(grp2)
# Out:
#      region        area
# 0    Africa    923768.0
# 1  Americas  18144858.0
# 2      Asia  16239582.0
# 3    Europe  17124442.0

# %%
fig,ax=plt.subplots(2,1)
ax[0].bar(grp['region'],grp['population'])
ax[0].set_title('Population by region')
ax[0].set_xlabel('Region')
ax[0].set_ylabel('Population')

ax[1].bar(grp2['region'],grp2['area'])
ax[1].set_title('Area by region')
ax[1].set_xlabel('Region')
ax[1].set_ylabel('Area')
plt.gcf().set_size_inches(15,15)

# %%
k=grp.merge(grp2)

# %%
sns.pairplot(k)
